# %% [markdown]
# # Logprobs with chatgroq and langchain

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model_name='llama3-70b-8192')
llm = llm.bind(logprobs=True)

# %%
msg = llm.invoke(("human", "how are you today"))

msg.response_metadata["logprobs"]["content"][:5]
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 msg = llm.invoke(("human", "how are you today"))
#       3 msg.response_metadata["logprobs"]["content"][:5]
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/langchain_core/runnables/base.py:4433, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    4427 def invoke(
#    4428     self,
#    4429     input: Input,
#    4430     config: Optional[RunnableConfig] = None,
#    4431     **kwargs: Optional[Any],
#    4432 ) -> Output:
# -> 4433     return self.bound.invoke(
#    4434         input,
#    4435         self._merge_configs(config),
#    4436         **{**self.kwargs, **kwargs},
#    4437     )
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:170, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     159 def invoke(
#     160     self,
#     161     input: LanguageModelInput,
#    (...)
#     165     **kwargs: Any,
#     166 ) -> BaseMessage:
#     167     config = ensure_config(config)
#     168     return cast(
#     169         ChatGeneration,
# --> 170         self.generate_prompt(
#     171             [self._convert_input(input)],
#     172             stop=stop,
#     173             callbacks=config.get("callbacks"),
#     174             tags=config.get("tags"),
#     175             metadata=config.get("metadata"),
#     176             run_name=config.get("run_name"),
#     177             run_id=config.pop("run_id", None),
#     178             **kwargs,
#     179         ).generations[0][0],
#     180     ).message
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:599, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     591 def generate_prompt(
#     592     self,
#     593     prompts: List[PromptValue],
#    (...)
#     596     **kwargs: Any,
#     597 ) -> LLMResult:
#     598     prompt_messages = [p.to_messages() for p in prompts]
# --> 599     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:456, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     454         if run_managers:
#     455             run_managers[i].on_llm_error(e, response=LLMResult(generations=[]))
# --> 456         raise e
#     457 flattened_outputs = [
#     458     LLMResult(generations=[res.generations], llm_output=res.llm_output)  # type: ignore[list-item]
#     459     for res in results
#     460 ]
#     461 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:446, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     443 for i, m in enumerate(messages):
#     444     try:
#     445         results.append(
# --> 446             self._generate_with_cache(
#     447                 m,
#     448                 stop=stop,
#     449                 run_manager=run_managers[i] if run_managers else None,
#     450                 **kwargs,
#     451             )
#     452         )
#     453     except BaseException as e:
#     454         if run_managers:
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/langchain_core/language_models/chat_models.py:671, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     669 else:
#     670     if inspect.signature(self._generate).parameters.get("run_manager"):
# --> 671         result = self._generate(
#     672             messages, stop=stop, run_manager=run_manager, **kwargs
#     673         )
#     674     else:
#     675         result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/langchain_groq/chat_models.py:247, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     242 message_dicts, params = self._create_message_dicts(messages, stop)
#     243 params = {
#     244     **params,
#     245     **kwargs,
#     246 }
# --> 247 response = self.client.create(messages=message_dicts, **params)
#     248 return self._create_chat_result(response)
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/groq/resources/chat/completions.py:283, in Completions.create(self, messages, model, frequency_penalty, function_call, functions, logit_bias, logprobs, max_tokens, n, presence_penalty, response_format, seed, stop, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     145 def create(
#     146     self,
#     147     *,
#    (...)
#     173     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     174 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     175     """
#     176     Creates a model response for the given chat conversation.
#     177
#    (...)
#     281       timeout: Override the client-level default timeout for this request, in seconds
#     282     """
# --> 283     return self._post(
#     284         "/openai/v1/chat/completions",
#     285         body=maybe_transform(
#     286             {
#     287                 "messages": messages,
#     288                 "model": model,
#     289                 "frequency_penalty": frequency_penalty,
#     290                 "function_call": function_call,
#     291                 "functions": functions,
#     292                 "logit_bias": logit_bias,
#     293                 "logprobs": logprobs,
#     294                 "max_tokens": max_tokens,
#     295                 "n": n,
#     296                 "presence_penalty": presence_penalty,
#     297                 "response_format": response_format,
#     298                 "seed": seed,
#     299                 "stop": stop,
#     300                 "stream": stream,
#     301                 "temperature": temperature,
#     302                 "tool_choice": tool_choice,
#     303                 "tools": tools,
#     304                 "top_logprobs": top_logprobs,
#     305                 "top_p": top_p,
#     306                 "user": user,
#     307             },
#     308             completion_create_params.CompletionCreateParams,
#     309         ),
#     310         options=make_request_options(
#     311             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     312         ),
#     313         cast_to=ChatCompletion,
#     314         stream=stream or False,
#     315         stream_cls=Stream[ChatCompletionChunk],
#     316     )
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/groq/_base_client.py:1225, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1211 def post(
#    1212     self,
#    1213     path: str,
#    (...)
#    1220     stream_cls: type[_StreamT] | None = None,
#    1221 ) -> ResponseT | _StreamT:
#    1222     opts = FinalRequestOptions.construct(
#    1223         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1224     )
# -> 1225     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/groq/_base_client.py:920, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     911 def request(
#     912     self,
#     913     cast_to: Type[ResponseT],
#    (...)
#     918     stream_cls: type[_StreamT] | None = None,
#     919 ) -> ResponseT | _StreamT:
# --> 920     return self._request(
#     921         cast_to=cast_to,
#     922         options=options,
#     923         stream=stream,
#     924         stream_cls=stream_cls,
#     925         remaining_retries=remaining_retries,
#     926     )
#
# File ~/miniconda3/envs/scalzi/lib/python3.11/site-packages/groq/_base_client.py:1018, in SyncAPIClient._request(self, cast_to, options, remaining_retries, stream, stream_cls)
#    1015         err.response.read()
#    1017     log.debug("Re-raising status error")
# -> 1018     raise self._make_status_error_from_response(err.response) from None
#    1020 return self._process_response(
#    1021     cast_to=cast_to,
#    1022     options=options,
#    (...)
#    1025     stream_cls=stream_cls,
#    1026 )
#
# BadRequestError: Error code: 400 - {'error': {'message': '`logprobs` is not supported with this model', 'type': 'invalid_request_error'}}

# %% [markdown]
# # Conclusion
# No logprobs with groq. Not a big one.
