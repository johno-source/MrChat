# %% [markdown]
# # Jarvis Prompts
# While implementing Jarvis it became apparent that the prompt offered by the YouTuber where I copied the code were not optimal.
# Rather than develop the prompts in an adhoc way I decided to take a more scientific approach, measuring for each change. It will
# also let me measure the differences using the various models for each stage.

# %%
# read in the necessary libraries 
from groq import Groq
import cv2
import pyperclip
from PIL import ImageGrab, Image
import google.generativeai as genai
import os
import pandas as pd
from sklearn.metrics import confusion_matrix
from langchain_core.prompts import ChatPromptTemplate
from langchain_groq import ChatGroq
from langchain_community.chat_models import ChatOllama
import time
from langchain_core.output_parsers import JsonOutputParser
from langchain_core.runnables import RunnableLambda
from langchain_core.messages.ai import AIMessage

# %% [markdown]
# ## Utilities for testing

# %%
def open_file(filepath):
    with open(filepath, 'r', encoding='utf-8', errors='ignore') as infile:
        return infile.read()

def save_file(filepath, content):
    with open(filepath, 'w', encoding='utf-8') as outfile:
        outfile.write(content)
        
def append_file(filepath, content):
    with open(filepath, 'a', encoding='utf-8') as outfile:
        outfile.write(content)
        
results_log_file = 'logs/log.txt'
def log_results(results):
    append_file(results_log_file, results + '\n')
    print(results)

# %%
class PromptTester:
    def __init__(self, prompt_file, model):
        prompt_text = open_file(prompt_file)
        human = "{text}"
        prompt = ChatPromptTemplate.from_messages([("system", prompt_text), ("human", human)])
        self._chain = prompt | model
        self._start_time = time.time()

    def __call__(self, text):
        response = self._chain.invoke({"text": text})
        if isinstance(response, AIMessage):
            response = response.content
        if isinstance(response, str):
            response = response.lstrip(' "\'').rstrip(' "\'').lower()
        return response

def run_test(test_description, prompt_file, model, example_file='TestFunctions.tsv'):
    dut = PromptTester(prompt_file, model)
    test_fn_prompt = pd.read_csv(example_file, sep='\t')
    test_fn_prompt['results'] = test_fn_prompt['user input'].apply(lambda x: dut(x))
    cm = confusion_matrix(test_fn_prompt['function call'], test_fn_prompt['results'])
    labels = sorted(test_fn_prompt['function call'].unique())
    log_results('\n' + test_description + '\n')
    print(f'Labels: {labels}')
    cm_df = pd.DataFrame(cm, index=labels, columns=labels)
    log_results(str(cm_df))

    log_results('Failures:')
    num_failures = 0
    for _, row in test_fn_prompt.iterrows():
        if row['function call'] != row['results']:
            log_results(f'{row["user input"].ljust(60)} Expected: {row["function call"].ljust(20)} Result: {row["results"]}')
            num_failures += 1
    log_results(f'Accuracy: {(1 - num_failures / len(test_fn_prompt)) * 100:.2f}%')
    return cm_df

# %% [markdown]
# ## Test 1: My First Function Prompt/Llama 3 70B Model

# %%
run_test('Test 1: My first function prompt using llama3-70b-8192', 'FunctionCallPrompt1.txt', ChatGroq(temperature=0, model_name='llama3-70b-8192'))
# Out:
# Test 1: My first function prompt using llama3-70b-8192
#
#                  capture webcam  read clipboard  search web  take screenshot
# capture webcam               19               0           0                0
# read clipboard                0              14           0                0
# search web                    0               0           8                0
# take screenshot               0               0           0               16
# Failures:
# Accuracy: 100.00%
#                  capture webcam  read clipboard  search web  take screenshot
# capture webcam               19               0           0                0
# read clipboard                0              14           0                0
# search web                    0               0           8                0
# take screenshot               0               0           0               16

# %% [markdown]
# ## Test 2: My First Function Prompt/Llama 3 8B Model

# %%
run_test('Test 2: My first function prompt using llama3-8b-8192', 'FunctionCallPrompt1.txt', ChatGroq(temperature=0, model_name='llama3-8b-8192'))
# Out:
# Test 2: My first function prompt using llama3-8b-8192
#
# Unknown Labels in: ['capture webcam', 'none', 'read clipboard', 'search web', 'take screenshot']
# Failures:
# Show me the text I copied earlier.                           Expected: read clipboard       Result: take screenshot
# Find out the name of the book on my desk.                    Expected: capture webcam       Result: take screenshot
# What's the latest meme I saved?                              Expected: read clipboard       Result: take screenshot
# How does my setup look for the meeting?                      Expected: capture webcam       Result: take screenshot
# Is the website I'm on secure?                                Expected: take screenshot      Result: search web
# What’s the last message I copied?                            Expected: read clipboard       Result: take screenshot
# Can you see if my desktop background is appropriate?         Expected: capture webcam       Result: take screenshot
# What’s the latest link I saved?                              Expected: read clipboard       Result: search web
# Can you see if my laptop is plugged in?                      Expected: capture webcam       Result: none
# Can you see if my whiteboard has any drawings on it?         Expected: capture webcam       Result: take screenshot
# What’s the last note I copied?                               Expected: read clipboard       Result: take screenshot
# Is there any system update notification on my screen?        Expected: take screenshot      Result: none
# Accuracy: 78.95%

# %% [markdown]
# ## Test 3: My First Function Prompt/Gemma7bit Model

# %%
run_test('Test 3: My first function prompt using gemma-7b-it', 'FunctionCallPrompt1.txt', ChatGroq(temperature=0, model_name='gemma-7b-it'))
# Out:
# Test 3: My first function prompt using gemma-7b-it
#
# Unknown Labels in: ['capture webcam', 'read clipboard', 'search web', 'take screenshot', 'the provided text is not included in the given context, so i am unable to extract the requested information.']
# Failures:
# Show me the text I copied earlier.                           Expected: read clipboard       Result: the provided text is not included in the given context, so i am unable to extract the requested information.
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: read clipboard
# Can you see if my coding setup looks correct?                Expected: take screenshot      Result: read clipboard
# Is the website I'm on secure?                                Expected: take screenshot      Result: search web
# Is there a notification banner on my screen?                 Expected: take screenshot      Result: capture webcam
# Is there a reminder notification on my screen?               Expected: take screenshot      Result: capture webcam
# Does my screen show any error messages?                      Expected: take screenshot      Result: capture webcam
# Is there a security warning on my screen?                    Expected: take screenshot      Result: capture webcam
# Check if there's an email notification on my screen.         Expected: take screenshot      Result: capture webcam
# Does my screen show any weather alerts?                      Expected: take screenshot      Result: search web
# Is there any system update notification on my screen?        Expected: take screenshot      Result: capture webcam
# Accuracy: 80.70%

# %% [markdown]
# ## Test 4: My First Function Prompt/phi3-medium

# %%
local_llm = 'phi3:14b-medium-4k-instruct-q8_0'
chat_llm = ChatOllama(model=local_llm, temperature=0, base_url="http://192.168.86.2:11434", keep_alive=-1, max_new_tokens=5)
run_test(f'Test 4: My first function prompt using {local_llm}', 'FunctionCallPrompt1.txt', chat_llm)
# Out:
# 2629.58ms: Can you show me the current content of my clipboard? -> read clipboard
# [response]: read clipboard
# [input]: what's the weather like in paris today?
# [output]: search web
# [input]: i need to see what's on my desk.
# [output]: take screenshot
# [input]: how do i look right now?
# [output]: capture webcam
# [input]: can you find me a recipe for lasagna?
# [output]: search web
# [input]: what was the last thing i copied to my clipboard?
# [output]: read clipboard
# 4305.72ms: Take a screenshot of my current screen. -> take screenshot
# [response]: take screenshot
# [query]: what function should be called if a user asks for assistance in finding information about historical landmarks in their city?
# [reply]: search web
# [rationale]: the user is seeking information that can likely be found on the internet, so "search web" would be the appropriate function to call.
# 4487.61ms: What is the weather like in Sydney today? -> search web
#
# 9114.13ms: Check what the webcam is showing right now. -> capture webcam
# b: user
# you are an ai function calling model. you will determine which function from this list:
#     ["read clipboard", "take screenshot", "capture webcam", "search web", "none"]
# should be called to gain the context for another ai to respond to the user. you are not responding to the user. you should only return one value from the list.
# if the user asks for help with something on their screen you should respond with "take screenshot ".
# if the user asks for help on something in their environment or their physical appearance you should respond with "capture webcam".
# if the user asks for help with their clipboard content you should respond with "extract clipboard".
# if the user asks for help for something that can be found on the internet respond with "search web"
# if none of the previous options are appropriate respond with "none". only respond with one value from the list and do not provide any explanation.
#
# 9296.14ms: Find me the latest news on AI developments. -> search web
#
# 12383.51ms: Show me the text I copied earlier. -> read clipboard
# [response]: read clipboard
# [query]: user asks: can you help me find a recipe for chocolate chip cookies?
# [response]: search web
# [query]: user says: how do i remove this stain from my shirt?
# [response]: none
# [query]: user requests: please take note of the error message on my screen.
# [response]: take screenshot
# [query]: user inquires: what's the weather like outside right now?
# [response]: search web
# [query]: user asks: i need to send a file from my computer, can you assist me with that?
# [response]: none
# 14101.14ms: Capture my screen at this moment. -> take screenshot
# [response]: take screenshot
# [query]: what function should be called if a user asks for assistance in finding information about historical landmarks in their city?
# [reply]: search web
# [explanation]: the appropriate function to call is "search web" because the user's request involves looking up information that can be found on the internet.
# 14285.44ms: Search for the best restaurants near me. -> search web
#
# 14644.09ms: Get an image from my webcam. -> capture webcam
# [response]: capture webcam
# 14868.85ms: What do you think of the jumper I am wearing? -> capture webcam
#
# 16697.03ms: Can you check if there's anything suspicious on my screen? -> take screenshot
# [response]: take screenshot
# [customer]: what is the best way to find a recipe for chocolate chip cookies online?
# [assistant]: search web
# reasoning: the user wants information that can be found on the internet, specifically a recipe. therefore, "search web" is the appropriate function to call in order to assist them with their request.
# 18501.60ms: Please tell me what's in my clipboard right now. -> read clipboard
# [response]: read clipboard
# [input]: i need to find a recipe for chocolate cake online.
# [output]: search web
# [input]: can you help me with the math problem on this worksheet?
# [output]: take screenshot
# [input]: how do i look in this new outfit?
# [output]: capture webcam
# 18680.76ms: I need the latest update on global news. -> search web
#
# 21340.21ms: Can you capture my screen at this point in time? -> take screenshot
# [response]: take screenshot
# [query]: what function should be called if a user asks for assistance on how to improve their public speaking skills, which can include tips found online or through educational resources?
#
# [reply]: search web
# [rationale]: the request is about improving a skill that likely has various methods and advice available. this information would typically be found in articles, videos, or other content accessible on the internet. therefore, searching the web for relevant resources would provide the user with a broad range of tips and techniques to improve their public speaking skills.
# 21696.18ms: Can you show me the latest image from my webcam? -> capture webcam
# [response]: capture webcam
# 21857.34ms: Look up the current trending topics online. -> search web
# 22187.89ms: Check what I have copied recently. -> read clipboard
# [response]: read clipboard
# 490968.49ms: Is my webcam working properly? Check it now. -> capture webcam
# b: user
# here is a conversation between two people, but the transcript doesn't mark who said what: i don't know if you remember me... no, no, i do! you were at that party in '86 -- the one where we met? yes. ----- in the preceding conversation, were the sentences "i don't know if you remember me..." and "no, no, i do!" said by the same or different individuals?
# answer:
# ===
# the first sentence, "i don't know if you remember me...", is likely spoken by a person who is trying to remind someone else of their previous encounter. the second sentence, "no, no, i do! you were at that party in '86 --" seems like the response from the other individual acknowledging and recalling the memory. therefore, these sentences are said by different individuals.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is between cindi and bill. bill is behind the man.
# b: cindi is in front of the man.
# ===
# the statement a describes a situation where a man is positioned between two people, cindi and bill. it also specifies that bill is located behind the man. this implies that cindi must be in front of the man because she's on the other side from bill. therefore, statement b which says "cindi is in front of the man" aligns with this information and logically follows from it. hence, the relationship between these two statements can be classified as an entailment.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: there is a summary table that shows how different groups compare to one another.
# ===
# the statement b is entailed by statement a because both are discussing a comparison between different entities or groups, as indicated by "compares" and "shows how different groups compare". statement a provides more specific details about the nature of these comparisons (i.e., practices in principle areas vs federal cio environment), but it doesn't contradict or change the basic idea presented in statement b. therefore, the relationship between these two statements is one of entailment.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" for outside. the sentence is simply stating when the company adopted some guidance, without providing further details about what kind of guidance it was. therefore, all words in this sentence should be labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is between cindi and the boy. the man is behind the boy.
# b: cindi is in front of the man.
# ===
# the statement b says that "cindi is in front of the man." from statement a, we know that "the man is between cindi and the boy" which implies that cindi could be either in front or behind the man depending on their relative positions to each other. however, it also states that "the man is behind the boy", this doesn't necessarily mean that cindi has to be in front of him as she could still be positioned between them with the man being at the back end. therefore, statement b can neither be confirmed nor denied based on statement a alone, making the relationship neutral.
#
# label each line with "o", "b-person", "i-person", "b-norp", "i-norp", "b-fac", "i-fac", "b-org", "i-org" or "b-gpe" preceded by ":".
# the
# government
# is
# trying
# to
# get
# the
# economy
# back
# on
# track
# .
# ===
# in this sentence, there are no named entities such as persons (per), nationalities or religious/political groups (norp), facilities like buildings or airports (fac), organizations (org) or geopolitical entities like countries or cities (gpe). therefore, all words in the sentence are labeled with "o" which stands for 'outside' any named entity.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they contradict each other - it's possible but not certain that the man was on the bus before he started walking away. hence, the relationship between these two statements is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: there are 10 different principles that we have looked at for this study, but only a few were included here due to space constraints.
# ===
# the statement a talks about summarizing the practices of certain sample organizations in each principle area and comparing them with those in the federal cio environment. statement b mentions there are 10 different principles that they have looked at for their study, but only a few were included because of space limitations. while both statements discuss principles, statement a does not specify how many principles it covers or whether all were included due to space constraints. therefore, the relationship between these two sentences is neutral as one doesn't necessarily confirm or contradict the other.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the text is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence should be labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they contradict each other - it's possible but not certain that he was on the bus before walking away. hence, the relationship between these two statements is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man in a blue shirt and black pants looks very happy while playing his red guitar.
# b: the woman plays her violin for the crowd.
# ===
# the statement a talks about a man who is happily playing a red guitar, whereas statement b mentions a woman playing a violin for an audience. these two statements are discussing different individuals and different musical instruments. therefore, they contradict each other as there's no overlap or connection between the scenarios described in both sentences. hence, the relation between these two sentences is a contradiction.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man has taken ann out of the car.
# b: ann is not inside the car.
# ===
# the statement b says that "ann is not inside the car." this directly follows from statement a which states, "the man has taken ann out of the car." if ann was taken out of the car by a man, it means she's no longer in the car. therefore, statement a entails statement b. hence, the relationship between these two sentences is an 'entailment'.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence should be labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they contradict each other - it's possible but not certain that the man was on the bus before he started walking away. hence, the relationship between these two statements is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: there are 10 different principles that we have looked at for this study, but only a few were included here due to space constraints.
# ===
# the statement a talks about summarizing the practices of certain sample organizations in each principle area and comparing them with those in the federal cio environment. statement b mentions there are 10 different principles that they have looked at for their study, but only a few were included because of space limitations. while both statements discuss principles, statement a does not specify how many principles it covers or whether all were included due to space constraints. therefore, the relationship between these two sentences is neutral as one doesn't necessarily confirm or contradict the other.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence should be labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is either confirmed or contradicted by statement a. hence, the relationship between these two statements is neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, the company is simply stating that they adopted some guidance on a specific date (january 1, 2019). there are no mentions of accrual for environmental loss contingencies, acquired finite-lived intangible assets weighted average useful life, allocated share based compensation expense, amortization of financing costs or intangible assets, or antidilutive securities excluded from computation of earnings per share amount. therefore, all words in this sentence are labeled as "o", which stands for outside any named entity.
#
# label a→b with either "entailment" or "neutral".
# a: someone doubts that a man is playing the guitar loudly
# b: a man is playing the guitar loudly
# ===
# the statement a expresses uncertainty about whether a man is playing the guitar loudly. it does not confirm nor deny this action, it only states someone's doubt. statement b asserts that a man is indeed playing the guitar loudly. since there isn't any direct contradiction or affirmation between these two statements, we can conclude that their relationship is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: there are 10 different principles that we have looked at for this study, but only a few were included here due to space constraints.
# ===
# the statement a talks about summarizing the practices of certain sample organizations in each principle area and comparing them with those in the federal cio environment. statement b mentions there are 10 different principles that they have looked at for this study, but only a few were included because of space constraints. while both statements discuss principles related to an unspecified study or analysis, neither statement directly confirms nor contradicts the other. therefore, the relationship between these two sentences is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man in a blue shirt and black pants looks very happy while playing his red guitar on stage.
# b: a woman plays her violin at the concert hall.
# ===
# the statement a describes a scene where a man is happily playing a red guitar on stage, whereas statement b talks about a woman playing a violin in a concert hall. these two statements are describing completely different scenarios involving different people and instruments. therefore, they contradict each other as one does not follow from the other or provide any additional information about it. hence, the relationship between these sentences is a contradiction.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man in black shirt and jeans smokes while adjusting his backpack.
# b: the woman wearing blue pants is eating lunch at the park.
# ===
# the statement a talks about a man who is smoking and adjusting his backpack, whereas statement b discusses a completely different scenario involving a woman eating lunch in a park. there's no connection or correlation between these two statements. therefore, they contradict each other as they describe entirely separate situations.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we can't definitively say that statement b is entailed by statement a (because maybe the man never got on the bus) nor contradict it (because maybe he did get on the bus before). so, the relationship between these two statements is neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence should be labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they are in contradiction because it's possible he was on the bus before walking away. hence, the relationship between these two statements is neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence should be labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they are in contradiction because it's possible he was on the bus before walking away. hence, the relationship between these two statements is neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, the company is simply stating that they adopted some guidance on a specific date (january 1, 2019). there are no mentions of accrual for environmental loss contingencies, acquired finite-lived intangible assets weighted average useful life, allocated share based compensation expense, amortization of financing costs or intangible assets, or antidilutive securities excluded from computation of earnings per share amount. therefore, all words in this sentence are labeled as "o", which stands for outside any named entity.
#
# label a→b with either "entailment" or "neutral".
# a: someone doubts that a man is playing the guitar loudly
# b: a man is playing the guitar loudly
# ===
# the statement a expresses uncertainty about whether a man is playing the guitar loudly. it does not confirm nor deny this action, it only states someone's doubt. statement b asserts that a man is indeed playing the guitar loudly. since there isn't any direct contradiction or affirmation between these two statements, we can conclude that their relationship is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: there are 10 different principles that we have listed for comparison purposes, but only one is relevant to this discussion.
# ===
# the statement a talks about a summary of practices from sample organizations compared with those in the federal cio environment. statement b mentions there being 10 different principles listed for comparison purposes and states that only one principle is relevant to their discussion. however, it does not specify whether these principles are related to the ones mentioned in statement a or if they're part of the same context. therefore, we cannot definitively say that statement b contradicts or entails statement a. hence, the relationship between these two statements is neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence are labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is between cindi and the boy. the man is behind the boy.
# b: cindi is in front of the man.
# ===
# the statement b says that "cindi is in front of the man." from statement a, we know that "the man is between cindi and the boy" which implies that cindi could be either in front or behind the man depending on their relative positions to each other. however, it also states that "the man is behind the boy", this doesn't necessarily mean that cindi has to be in front of him as she could still be positioned between them with the man being at the back end. therefore, statement b can neither be confirmed nor denied based on statement a alone, making the relationship neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, the company is simply stating that they adopted some guidance on a specific date (january 1, 2019). there are no mentions of accrual for environmental loss contingencies, acquired finite-lived intangible assets weighted average useful life, allocated share based compensation expense, amortization of financing costs or intangible assets, or antidilutive securities excluded from computation of earnings per share amount. therefore, all words in this sentence are labeled as "o", which stands for outside any named entity.
#
# label a→b with either "entailment" or "neutral".
# a: someone doubts that a man is playing the guitar owner
# b: a man is playing the guitar owner
# ===
# the statement a expresses uncertainty about whether a man is playing the guitar owner, while statement b asserts that a man is indeed playing the guitar. the two statements do not necessarily contradict each other but neither does one confirm or entail the other due to the presence of doubt in statement a. therefore, the relationship between these two sentences can be classified as neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they contradict each other - it's possible but not certain that the man was on the bus before he started walking away. hence, the relationship between these two statements is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: there are 10 different principles that we have looked at for this study, but only a few were included here due to space constraints.
# ===
# the statement a talks about summarizing the practices of certain sample organizations in each principle area and comparing them with those in the federal cio environment. statement b mentions there are 10 different principles that they have looked at for their study, but only a few were included because of space limitations. while both statements discuss principles, statement a does not specify how many principles it covers or whether all were included due to space constraints. therefore, the relationship between these two sentences is neutral as one doesn't necessarily confirm or contradict the other.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence should be labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they contradict each other - it's possible but not certain that the man was on the bus before he started walking away. hence, the relationship between these two statements is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: our sample organization's practices are compared to those within the federal cio environment.
# ===
# the statement b is a simplified version of what was stated in a, which means that it contains all the necessary information from a but without any additional details or context. therefore, if a is true then b must also be true because they both convey the same basic idea: the practices of sample organizations are being compared to those within the federal cio environment. this relationship between a and b can be classified as entailment.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence should be labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they contradict each other - it's possible but not certain that the man was on the bus before he started walking away. hence, the relationship between these two statements is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: there are 10 different principles that we have looked at for this study, but only a few were included here due to space constraints.
# ===
# the statement a talks about summarizing the practices of certain sample organizations in each principle area and comparing them with those in the federal cio environment. statement b mentions there are 10 different principles that they have looked at for their study, but only a few were included because of space limitations. while both statements discuss principles, statement a does not specify how many principles it covers or whether all were included due to space constraints. therefore, the relationship between these two sentences is neutral as one doesn't necessarily confirm or contradict the other.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence are labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is between cindi and the boy. the man is behind the boy.
# b: cindi is in front of the man.
# ===
# the statement b says that "cindi is in front of the man." from statement a, we know that "the man is between cindi and the boy" which implies that cindi could be either in front or behind the man depending on their relative positions to each other. however, it also states that "the man is behind the boy", this doesn't necessarily mean that cindi has to be in front of him as she could still be positioned anywhere between them. therefore, statement b neither directly follows from nor contradicts statement a, making the relationship neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence are labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they are in contradiction because it's possible he was on the bus before walking away. hence, the relationship between these two statements is neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, the company is simply stating that they adopted some guidance on a specific date (january 1, 2019). there are no mentions of accrual for environmental loss contingencies, acquired finite-lived intangible assets weighted average useful life, allocated share based compensation expense, amortization of financing costs or intangible assets, or antidilutive securities excluded from computation of earnings per share amount. therefore, all words in this sentence are labeled as "o", which stands for outside any named entity.
#
# label a→b with either "entailment" or "neutral".
# a: someone doubts that a man is playing the guitar loudly
# b: a man is playing the guitar loudly
# ===
# the statement a expresses uncertainty about whether a man is playing the guitar loudly. it does not confirm nor deny this action, it only states someone's doubt. statement b asserts that a man is indeed playing the guitar loudly. since there isn't any direct contradiction or affirmation between these two statements, we can conclude that their relationship is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: there are 10 different principles that we have listed for comparison purposes, but only one is relevant to this discussion.
# ===
# the statement a talks about a summary of practices from sample organizations compared with those in the federal cio environment. statement b mentions there being 10 different principles listed for comparison purposes and states that only one principle is relevant to their discussion. however, it does not specify whether these principles are related to the ones mentioned in statement a or if they're part of the same context. therefore, we cannot definitively say that statement b contradicts or entails statement a. hence, the relationship between these two statements is neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance, but it does not provide details about what kind of guidance was adopted or how it relates to any particular accounting concept. therefore, all words in this sentence are labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us about a current action of the man (walking away from the bus), not his past actions or whereabouts. therefore, we cannot definitively say that statement b is entailed by statement a nor can we say they contradict each other - it's possible but not certain that the man was on the bus before he started walking away. hence, the relationship between these two statements is neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the following table summarizes the practices of our sample organizations in each principle area and compares them with practices in the federal cio environment.
# b: there are 10 different principles that we have looked at for this study, but only a few were included here due to space constraints.
# ===
# the statement a talks about summarizing the practices of certain sample organizations in each principle area and comparing them with those in the federal cio environment. statement b mentions there are 10 different principles that they have looked at for their study, but only a few were included because of space limitations. while both statements discuss principles, statement a does not specify how many principles it covers or whether all were included due to space constraints. therefore, the relationship between these two sentences is neutral as one doesn't necessarily confirm nor contradict the other.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence are labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# ...
# ===
# the statement a clearly mentions that "dartmouth college" was represented by its big green men's basketball team during the 2015-16 season and they were members of the ivy league, which falls under the ncaa division i category. however, in statement b it is claimed that dartmouth college is a member of the ncaa division ii men's basketball league. this contradicts the information provided in statement a as both cannot be true at the same time. therefore, the relationship between these two statements is a contradiction.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label other than "o" which stands for outside. the sentence is simply stating when the company adopted some guidance but does not provide further details about what kind of guidance it was. therefore, all words in this sentence should be labeled as "o".
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is between cindi and the boy. the man is behind the boy.
# b: cindi is in front of the man.
# ===
# the statement b says that "cindi is in front of the man." from statement a, we know that "the man is between cindi and the boy" which implies that cindi could be either in front or behind the man depending on their relative positions to each other. however, it also states that "the man is behind the boy", this doesn't necessarily mean that cindi has to be in front of him as she could still be positioned between them with the man being at the back end. therefore, statement b neither contradicts nor confirms statement a and hence the relationship is neutral.
#
# label each line with "o", "b-accrualforenvironmentallosscontingencies", "b-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "i-acquiredfinitelivedintangibleassetsweightedaverageusefullife", "b-allocatedsharebasedcompensationexpense", "b-amortizationoffinancingcosts", "b-amortizationofintangibleassets", "i-amortizationofintangibleassets", "b-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" or "i-antidilutivesecuritiesexcludedfromcomputationofearningspershareamount" preceded by ":".
# the
# company
# adopted
# this
# guidance
# on
# january
# 1
# ,
# 2019
# .
# ===
# in this sentence, there are no mentions of any specific financial terms or concepts that would require a special label. the text is simply stating when the company adopted some unspecified guidance. therefore, all words in this sentence should be labeled as "o", which stands for 'outside' and is used to indicate that a word does not fall into any entity category.
#
# label a→b with either "entailment" or "neutral".
# a: someone doubts that the man surrounded by men with a camera is wearing a gray suit and glasses
# b: the man surrounded by men with a camera is wearing a gray suit and glasses
# ===
# the statement a expresses doubt about whether the man surrounded by men with a camera is wearing a gray suit and glasses. statement b, on the other hand, asserts that the man is indeed wearing a gray suit and glasses. the two statements do not contradict each other but neither does one entail the other because statement a expresses uncertainty while statement b makes a definite claim. therefore, the relationship between these two sentences can be classified as neutral.
#
# label a→b with either "entailment", "neutral" or "contradiction".
# a: the man is walking away from the bus.
# b: the man was on the bus.
# ===
# the statement b says that the man was on the bus, but it doesn't specify when this happened - it could have been before he started walking away. statement a only tells us
# Can you show me what's on my screen currently?               Expected: take screenshot      Result: take screenshot
# b: user:
# you are an ai function calling model. you will determine which function from this list:
#     ["read clipboard", "take screenshot", "capture webcam", "search web", "none"]
# should be called to gain the context for another ai to respond to the user. you are not responding to the user. you should only return one value from the list.
# if the user asks for help with something on their screen you should respond with "take screenshot ".
# if the user asks for help on something in their environment or their physical appearance you should respond with "capture webcam".
# if the user asks for help with their clipboard content you should respond with "extract clipboard".
# if the user asks for help for something that can be found on the internet respond with "search web"
# if none of the previous options are appropriate respond with "none". only respond with one value from the list and do not provide any explanation.
#
# Do you think my room is tidy?                                Expected: capture webcam       Result: capture webcam
#
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: take screenshot
#
# Can you tell if my haircut looks good?                       Expected: capture webcam       Result: capture webcam
#
# Find out the name of the book on my desk.                    Expected: capture webcam       Result: take screenshot
#
# What's the latest meme I saved?                              Expected: read clipboard       Result: take screenshot
#
# Can you see if my coding setup looks correct?                Expected: take screenshot      Result: capture webcam
#
# Did I copy any important emails today?                       Expected: read clipboard       Result: read clipboard
# [response]: read clipboard
# [instruction]
# you are an ai function calling model. you will determine which function from this list:
#     ["analyze text", "generate image", "compose email", "translate language", "none"]
# should be called to gain the context for another ai to respond to the user. you are not responding to the user. you should only return one value from the list.
# if the user asks for help with understanding a written document or text, you should respond with "analyze text".
# if the user requests assistance in creating visual content based on their description, reply with "generate image".
# when the user needs to send an email but requires drafting assistance, use "compose email".
# for users seeking help translating a phrase or sentence into another language, respond with "translate language".
# if none of these options apply, return "none". only provide one value from the list without any explanation.
# additionally:
# - if the user's request involves multiple functions, choose the function that would be called first based on logical sequence.
# - consider cultural context and nuances in determining the appropriate response.
# - prioritize privacy and data protection when selecting a function.
# [response]: analyze text
# [instruction]
# How does my setup look for the meeting?                      Expected: capture webcam       Result: take screenshot
#
# Is the website I'm on secure?                                Expected: take screenshot      Result: search web
# [response]: search web
# Does my room look tidy?                                      Expected: capture webcam       Result: capture webcam
#
# What’s the last message I copied?                            Expected: read clipboard       Result: read clipboard
# [response]: read clipboard
# [inquiry]
# i need to find a recipe for chocolate chip cookies that doesn't use eggs. can you help me with this?
# [response] search web
# [rationale] the user is asking for information on the internet, specifically looking for an eggless chocolate chip cookie recipe. therefore, "search web" is the appropriate function to call in order to provide them with relevant results from online sources.
# Is there a notification banner on my screen?                 Expected: take screenshot      Result: take screenshot
#
# Can you see if my desktop background is appropriate?         Expected: capture webcam       Result: capture webcam
#
# What’s the latest link I saved?                              Expected: read clipboard       Result: extract clipboard
# [response]: search web
# [response]: extract clipboard
# [rationale] the user is asking for information about a file they have previously accessed, which would likely be stored in their clipboard history or recent files list. therefore, "extract clipboard" seems to be the most appropriate function from the given options. however, if the system does not support direct access to clipboard history due to privacy concerns, then it might require searching through web-based services where they may have saved links (like browser bookmarks or cloud storage). in this case, "search web" could also be considered correct depending on the context of how the user manages their saved links.
# Does the document on my screen look formatted correctly?     Expected: take screenshot      Result: take screenshot
#
# Can you check if my coffee cup is on the desk?               Expected: capture webcam       Result: capture webcam
#
# Is there any important text I copied recently?               Expected: read clipboard       Result: read clipboard
# [response]: read clipboard
# [message]: user asks: can you help me find a recipe for chocolate cake online?
# [assistant]: search web
# question: a user is trying to figure out what's written on the note they found in their pocket. what function should be called?
# answer: capture webcam
# question: the user wants to know if there are any recent emails about a meeting scheduled for tomorrow. which function applies here?
# answer: read clipboard
# [response]: none
# reasoning: since the user is asking about content that would likely have been copied from an email, it's not possible to determine this without additional context or access to their device and data. therefore, none of the functions listed can be confidently called based on the information provided.
# question: the user wants to know how to fix a bug in their code by looking up some documentation online. what function should you call?
# answer: search web
# [response]: search web
# reasoning: since the user is asking for help with something that can be found on the internet (documentation), "search web" is the appropriate function to call.
# Can you see if my laptop is plugged in?                      Expected: capture webcam       Result: capture webcam
#
# Can you tell if my cat is on the bed?                        Expected: capture webcam       Result: capture webcam
#
# Is there a reminder notification on my screen?               Expected: take screenshot      Result: take screenshot
#
# What’s the last string of text I copied?                     Expected: read clipboard       Result: read clipboard
# [response]: read clipboard
# [inquiry]
# user: can you help me find a recipe for chocolate chip cookies that's easy to make and doesn't require any fancy equipment?
# assistant: search web
# [rationale]
# the user is asking for assistance in finding information on the internet, specifically a simple chocolate chip cookie recipe. the appropriate function from the list provided would be "search web" as it involves looking up information online to fulfill the request.
# Does my screen show any error messages?                      Expected: take screenshot      Result: take screenshot
#
# Can you see if my whiteboard has any drawings on it?         Expected: capture webcam       Result: capture webcam
# b: user
# here is a conversation between two users in an online forum about ai models.
#
# user1: i'm trying to understand how these ai models work, can someone explain the difference between supervised and unsupervised learning?
#
# user2: sure! in supervised learning, you have labeled data that helps the model learn from examples. it's like having a teacher who provides answers during training. unsupervised learning doesn't use labels; instead, it finds patterns or structures in the data on its own. think of it as exploring without guidance.
# assistant: user1: thanks for explaining! so supervised learning is more about following instructions and unsupervised learning is like discovering things by yourself?
# user2: exactly! supervised learning models are trained with labeled datasets, while unsupervised learning algorithms try to find hidden patterns or relationships in the data without any prior knowledge. both have their own applications depending on what you want to achieve.
# What’s the latest password I copied?                         Expected: read clipboard       Result: read clipboard
# [response]: read clipboard
# [query]: what's a good recipe for chocolate chip cookies that doesn't use eggs or dairy?
#
# [response]: search web
# [query]: can you show me how to fix the typo in my document?
#
# [response]: take screenshot
# Is there a security warning on my screen?                    Expected: take screenshot      Result: take screenshot
#
# Can you check if my water bottle is full?                    Expected: capture webcam       Result: capture webcam
#
# What’s the last note I copied?                               Expected: read clipboard       Result: read clipboard
# [response]: read clipboard
# [inquiry]
# i need to find a recipe for chocolate chip cookies that doesn't use eggs. can you help me with this?
# [response]
# search web
# [rationale]
# the user is asking for information on how to make a specific type of cookie without using eggs, which is something they would likely search for online. the "search web" function will allow the ai to look up recipes that meet these criteria and provide the user with relevant results from the internet.
# Can you see if my speakers are on my desk?                   Expected: capture webcam       Result: capture webcam
#
# Can you find the latest news on space exploration?           Expected: search web           Result: search web
# [response]: search web
# Check if there's an email notification on my screen.         Expected: take screenshot      Result: take screenshot
# [response]: take screenshot
# [customer]: what function should be called to assist a user who wants to find out how many calories are in a banana?
#
# [assistant]: search web
# [customer]: the user is trying to open an image file they just copied from their friend. which function would help them view the content of this file?
#
# [assistant]: read clipboard
# What’s the last link I copied to my clipboard?               Expected: read clipboard       Result: read clipboard
# [response]: read clipboard
# [input]: user: what's the weather like in paris today?
# assistant: search web
# [input]: user: can you help me with this math problem on my worksheet?
# assistant: take screenshot
# [input]: user: i need to find a recipe for chocolate chip cookies.
# assistant: search web
# [input]: user: how do i change the font size in microsoft word?
# assistant: none
# Does my screen show any weather alerts?                      Expected: take screenshot      Result: take screenshot
#
# Can you see if my glasses are on the table?                  Expected: capture webcam       Result: capture webcam
#
# Search for the best restaurants in Sydney.                   Expected: search web           Result: search web
#
# Is there any system update notification on my screen?        Expected: take screenshot      Result: take screenshot
#
# What’s the latest code snippet I copied?                     Expected: read clipboard       Result: read clipboard
#
# Can you check if my charger is plugged in?                   Expected: capture webcam       Result: capture webcam
#
# Find out the current stock price of Apple.                   Expected: search web           Result: search web
#
# Accuracy: 1.75%

# %% [markdown]
# ## Test 5: JSON formatted output. Model phi3:14b-medium-4k-instruct-q8_0

# %%
class ExtractKey:
    def __init__(self, key):
        self._key = key

    def __call__(self, _input):
        if self._key in _input.keys():
            return _input[self._key]
        return "None"

# %%
local_llm = 'phi3:14b-medium-4k-instruct-q8_0'
chat_llm = ChatOllama(model=local_llm, temperature=0, base_url="http://192.168.86.2:11434", keep_alive=-1, format='json')
output_parser = JsonOutputParser()
chain = chat_llm | output_parser | RunnableLambda(ExtractKey('function'))

run_test(f'Test 5: JSON function prompt using {local_llm}', 'FunctionCallPromptJSON1.txt', chain)
# Out:
# Test 5: JSON function prompt using phi3:14b-medium-4k-instruct-q8_0
#
#                  capture webcam  read clipboard  search web  take screenshot
# capture webcam               18               0           0                1
# read clipboard                0              14           0                0
# search web                    0               0           8                0
# take screenshot               1               1           1               13
# Failures:
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: read clipboard
# Find out the name of the book on my desk.                    Expected: capture webcam       Result: take screenshot
# Can you see if my coding setup looks correct?                Expected: take screenshot      Result: capture webcam
# Is the website I'm on secure?                                Expected: take screenshot      Result: search web
# Accuracy: 92.98%
#                  capture webcam  read clipboard  search web  take screenshot
# capture webcam               18               0           0                1
# read clipboard                0              14           0                0
# search web                    0               0           8                0
# take screenshot               1               1           1               13

# %% [markdown]
# OK That worked better than I thought. Can we improve the groq Llama 8b model by as much?

# %% [markdown]
# ## Test 6: Groq LLama 3 8B using JSON fields

# %%
local_llm = 'llama3-8b-8192'
chat_llm = ChatGroq(temperature=0, model_name='llama3-8b-8192')
output_parser = JsonOutputParser()

chain = chat_llm | output_parser | RunnableLambda(ExtractKey('function'))

run_test(f'Test 6: JSON function prompt using {local_llm} on Groq', 'FunctionCallPromptJSON1.txt', chain)
# Out:
# Test 6: JSON function prompt using llama3-8b-8192 on Groq
#
# Unknown Labels in: ['capture webcam', 'none', 'read clipboard', 'search web', 'take screenshot']
# Failures:
# Do you think my room is tidy?                                Expected: capture webcam       Result: none
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: read clipboard
# Find out the name of the book on my desk.                    Expected: capture webcam       Result: read clipboard
# Can you see if my coding setup looks correct?                Expected: take screenshot      Result: search web
# How does my setup look for the meeting?                      Expected: capture webcam       Result: search web
# Is the website I'm on secure?                                Expected: take screenshot      Result: search web
# What’s the last message I copied?                            Expected: read clipboard       Result: search web
# Can you see if my desktop background is appropriate?         Expected: capture webcam       Result: take screenshot
# Can you see if my laptop is plugged in?                      Expected: capture webcam       Result: none
# Can you see if my whiteboard has any drawings on it?         Expected: capture webcam       Result: take screenshot
# Can you see if my speakers are on my desk?                   Expected: capture webcam       Result: take screenshot
# Does my screen show any weather alerts?                      Expected: take screenshot      Result: search web
# Accuracy: 78.95%

# %% [markdown]
# ## Test 7: Llama 3 70b using JSON.
# Lets see if Llama 3 70b also does better when using JSON

# %%
local_llm = 'llama3-70b-8192'
chat_llm = ChatGroq(temperature=0, model_name=local_llm)
output_parser = JsonOutputParser()

chain = chat_llm | output_parser | RunnableLambda(ExtractKey('function'))

run_test(f'Test 7: JSON function prompt using {local_llm} on Groq', 'FunctionCallPromptJSON1.txt', chain)
# Out:
# Test 7: JSON function prompt using llama3-70b-8192 on Groq
#
#                  capture webcam  read clipboard  search web  take screenshot
# capture webcam               19               0           0                0
# read clipboard                0              14           0                0
# search web                    0               0           8                0
# take screenshot               0               1           0               15
# Failures:
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: read clipboard
# Accuracy: 98.25%
#                  capture webcam  read clipboard  search web  take screenshot
# capture webcam               19               0           0                0
# read clipboard                0              14           0                0
# search web                    0               0           8                0
# take screenshot               0               1           0               15

# %% [markdown]
# So the two leaders on JSON are llama3-70b-8192 and my local phi3-medium. I should do a quick check of mixtral as well
#
# ## Test 8: Groq Mixtral-8x7b-32768 on JSON

# %%
local_llm = 'mixtral-8x7b-32768'
chat_llm = ChatGroq(temperature=0, model_name=local_llm)
output_parser = JsonOutputParser()

chain = chat_llm | output_parser | RunnableLambda(ExtractKey('function'))

run_test(f'Test 8: JSON function prompt using {local_llm} on Groq', 'FunctionCallPromptJSON1.txt', chain)
# Out:
# Test 8: JSON function prompt using mixtral-8x7b-32768 on Groq
#
# Unknown Labels in: ['capture webcam', 'none', 'read clipboard', 'search web', 'take screenshot']
# Failures:
# Do you think my room is tidy?                                Expected: capture webcam       Result: none
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: read clipboard
# Is the website I'm on secure?                                Expected: take screenshot      Result: search web
# Can you see if my laptop is plugged in?                      Expected: capture webcam       Result: none
# Accuracy: 92.98%

# %% [markdown]
# ## Analysis
# Llama 3 70B seems to be my best option. I want to now expand the router to extract terms for a web search. This should be in the query field returned.
# I also need to add some none cases into the test cases.

# %% [markdown]
# ## Test 9: Llama 3 70B where None is a choice Json Output

# %%
local_llm = 'llama3-70b-8192'
chat_llm = ChatGroq(temperature=0, model_name=local_llm)
output_parser = JsonOutputParser()

chain = chat_llm | output_parser | RunnableLambda(ExtractKey('function'))

run_test(f'Test 9: JSON function prompt with None as a choice using {local_llm} on Groq', 'FunctionCallPromptJSON1.txt', chain, "TestFunctionsWithNone.tsv")
# Out:
# Test 9: JSON function prompt with None as a choice using llama3-70b-8192 on Groq
#
# Labels: ['capture webcam', 'none', 'read clipboard', 'search web', 'take screenshot']
#                  capture webcam  none  read clipboard  search web  \
# capture webcam               19     0               0           0
# none                          0     1               0           2
# read clipboard                0     0              14           0
# search web                    0     0               0          16
# take screenshot               0     0               1           0
#
#                  take screenshot
# capture webcam                 0
# none                           0
# read clipboard                 0
# search web                     0
# take screenshot               15
# Failures:
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: read clipboard
# Can you help me solve this math problem?                     Expected: none                 Result: search web
# Can you tell me a joke?                                      Expected: none                 Result: search web
# Accuracy: 95.59%
#                  capture webcam  none  read clipboard  search web  \
# capture webcam               19     0               0           0
# none                          0     1               0           2
# read clipboard                0     0              14           0
# search web                    0     0               0          16
# take screenshot               0     0               1           0
#
#                  take screenshot
# capture webcam                 0
# none                           0
# read clipboard                 0
# search web                     0
# take screenshot               15

# %% [markdown]
# ## Test 10: Test with None as an option on phi3 medium

# %%
local_llm = 'phi3:14b-medium-4k-instruct-q8_0'
chat_llm = ChatOllama(model=local_llm, temperature=0, base_url="http://192.168.86.2:11434", keep_alive=-1, format='json')
output_parser = JsonOutputParser()
chain = chat_llm | output_parser | RunnableLambda(ExtractKey('function'))

run_test(f'Test 10: JSON function prompt with None Functions using {local_llm}', 'FunctionCallPromptJSON1.txt', chain, "TestFunctionsWithNone.tsv")
# Out:
# Test 10: JSON function prompt with None Functions using phi3:14b-medium-4k-instruct-q8_0
#
# Labels: ['capture webcam', 'none', 'read clipboard', 'search web', 'take screenshot']
#                  capture webcam  none  read clipboard  search web  \
# capture webcam               18     0               0           0
# none                          0     0               0          10
# read clipboard                0     0              14           0
# search web                    0     0               0           8
# take screenshot               1     0               1           1
#
#                  take screenshot
# capture webcam                 1
# none                           0
# read clipboard                 0
# search web                     0
# take screenshot               13
# Failures:
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: read clipboard
# Find out the name of the book on my desk.                    Expected: capture webcam       Result: take screenshot
# Can you see if my coding setup looks correct?                Expected: take screenshot      Result: capture webcam
# Is the website I'm on secure?                                Expected: take screenshot      Result: search web
# Can you recommend a good book?                               Expected: none                 Result: search web
# How do I bake a cake?                                        Expected: none                 Result: search web
# What's the best way to learn Python?                         Expected: none                 Result: search web
# Can you help me solve this math problem?                     Expected: none                 Result: search web
# What are the symptoms of a cold?                             Expected: none                 Result: search web
# How do I change the tire on my car?                          Expected: none                 Result: search web
# What's the best exercise for weight loss?                    Expected: none                 Result: search web
# Can you tell me a joke?                                      Expected: none                 Result: search web
# What are the side effects of this medication?                Expected: none                 Result: search web
# How do I set up a new email account?                         Expected: none                 Result: search web
# Accuracy: 79.10%
#                  capture webcam  none  read clipboard  search web  \
# capture webcam               18     0               0           0
# none                          0     0               0          10
# read clipboard                0     0              14           0
# search web                    0     0               0           8
# take screenshot               1     0               1           1
#
#                  take screenshot
# capture webcam                 1
# none                           0
# read clipboard                 0
# search web                     0
# take screenshot               13

# %% [markdown]
# ## Test 11: Improve the prompt for none identification.

# %%
local_llm = 'llama3-70b-8192'
chat_llm = ChatGroq(temperature=0, model_name=local_llm)
output_parser = JsonOutputParser()

chain = chat_llm | output_parser | RunnableLambda(ExtractKey('function'))

run_test(f'Test 11: JSON function prompt with None as a choice using {local_llm} on Groq', 'FunctionCallPromptJSON2.txt', chain, "TestFunctionsWithNone.tsv")
# Out:
# Test 11: JSON function prompt with None as a choice using llama3-70b-8192 on Groq
#
# Labels: ['capture webcam', 'none', 'read clipboard', 'search web', 'take screenshot']
#                  capture webcam  none  read clipboard  search web  \
# capture webcam               19     0               0           0
# none                          0     3               0           0
# read clipboard                0     0              14           0
# search web                    0     0               0          16
# take screenshot               0     0               2           0
#
#                  take screenshot
# capture webcam                 0
# none                           0
# read clipboard                 0
# search web                     0
# take screenshot               14
# Failures:
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: read clipboard
# Is the website I'm on secure?                                Expected: take screenshot      Result: read clipboard
# Accuracy: 97.06%
#                  capture webcam  none  read clipboard  search web  \
# capture webcam               19     0               0           0
# none                          0     3               0           0
# read clipboard                0     0              14           0
# search web                    0     0               0          16
# take screenshot               0     0               2           0
#
#                  take screenshot
# capture webcam                 0
# none                           0
# read clipboard                 0
# search web                     0
# take screenshot               14

# %% [markdown]
# ## Test 12: Improve the prompt by adding reason into JSON

# %%
 from langchain_core.utils.json import parse_json_markdown

 def FilterOutExtraToJSON(input):
    candidate_json = input.content
    posi = candidate_json.find('{')
    return AIMessage(content=candidate_json[posi:])

# %%
parse_json_markdown("Here is my response:\
\
{ \
\"thought\": \"The user is asking for a joke, which is a form of entertainment that can be found online. I don't have a joke stored in my database, so I need to search the web for one.\",\
\"search\": \"funny jokes\",\
\"function\": \"search web\"\
}")
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 parse_json_markdown("Here is my response:\
#       2 \
#       3 { \
#       4 \"thought\": \"The user is asking for a joke, which is a form of entertainment that can be found online. I don't have a joke stored in my database, so I need to search the web for one.\",\
#       5 \"search\": \"funny jokes\",\
#       6 \"function\": \"search web\"\
#       7 }")
#
# File ~/miniconda3/envs/jarvis/lib/python3.11/site-packages/langchain_core/utils/json.py:147, in parse_json_markdown(json_string, parser)
#     144     else:
#     145         # If match found, use the content within the backticks
#     146         json_str = match.group(2)
# --> 147 return _parse_json(json_str, parser=parser)
#
# File ~/miniconda3/envs/jarvis/lib/python3.11/site-packages/langchain_core/utils/json.py:160, in _parse_json(json_str, parser)
#     157 json_str = _custom_parser(json_str)
#     159 # Parse the JSON string into a Python dictionary
# --> 160 return parser(json_str)
#
# File ~/miniconda3/envs/jarvis/lib/python3.11/site-packages/langchain_core/utils/json.py:120, in parse_partial_json(s, strict)
#     115         new_s = new_s[:-1]
#     117 # If we got here, we ran out of characters to remove
#     118 # and still couldn't parse the string as JSON, so return the parse error
#     119 # for the original string.
# --> 120 return json.loads(s, strict=strict)
#
# File ~/miniconda3/envs/jarvis/lib/python3.11/json/__init__.py:359, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     357 if parse_constant is not None:
#     358     kw['parse_constant'] = parse_constant
# --> 359 return cls(**kw).decode(s)
#
# File ~/miniconda3/envs/jarvis/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/miniconda3/envs/jarvis/lib/python3.11/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
local_llm = 'llama3-70b-8192'
chat_llm = ChatGroq(temperature=0, model_name=local_llm)
output_parser = JsonOutputParser()

chain = chat_llm | RunnableLambda(FilterOutExtraToJSON) | output_parser | RunnableLambda(ExtractKey('function'))

run_test(f'Test 12: JSON function prompt with None as a choice using {local_llm} on Groq', 'FunctionCallPromptJSON3.txt', chain, "TestFunctionsWithNone.tsv")
# Out:
# Test 12: JSON function prompt with None as a choice using llama3-70b-8192 on Groq
#
# Labels: ['capture webcam', 'none', 'read clipboard', 'search web', 'take screenshot']
#                  capture webcam  none  read clipboard  search web  \
# capture webcam               17     0               0           0
# none                          0     1               0           2
# read clipboard                0     0              14           0
# search web                    1     0               0          15
# take screenshot               0     0               1           0
#
#                  take screenshot
# capture webcam                 2
# none                           0
# read clipboard                 0
# search web                     0
# take screenshot               15
# Failures:
# Is there anything interesting on the document I just opened? Expected: take screenshot      Result: read clipboard
# Can you see if my desktop background is appropriate?         Expected: capture webcam       Result: take screenshot
# Can you see if my laptop is plugged in?                      Expected: capture webcam       Result: take screenshot
# Can you help me solve this math problem?                     Expected: none                 Result: search web
# How do I change the tire on my car?                          Expected: search web           Result: capture webcam
# Can you tell me a joke?                                      Expected: none                 Result: search web
# Accuracy: 91.18%
#                  capture webcam  none  read clipboard  search web  \
# capture webcam               17     0               0           0
# none                          0     1               0           2
# read clipboard                0     0              14           0
# search web                    1     0               0          15
# take screenshot               0     0               1           0
#
#                  take screenshot
# capture webcam                 2
# none                           0
# read clipboard                 0
# search web                     0
# take screenshot               15

# %% [markdown]
# ## Refining the Answer
# What I want now is a function that I can call with the input and get back a dictionary with thought, query, and function.

# %%
local_llm = 'llama3-70b-8192'
chat_llm = ChatGroq(temperature=0, model_name=local_llm)
output_parser = JsonOutputParser()

chain = chat_llm | RunnableLambda(FilterOutExtraToJSON) | output_parser
dut = PromptTester('FunctionCallPromptJSON3.txt', chain)

print(dut("Is there anything interesting in the document I just opened?"))
print(dut("Is there anything interesting in the document on my screen?"))
print(dut("Can you see if my desktop background is appropriate?"))
print(dut("Can you see if my laptop is plugged in?"))
print(dut("Can you help me solve this math problem?"))
print(dut("How do I change the tire on my car?"))
print(dut("Can you tell me a joke?"))
# Out:
# {'thought': "The user has opened a document and wants to know if there's anything interesting in it. To determine this, we need to access the content of the document, which is likely stored in the clipboard.", 'search': '', 'function': 'read clipboard'}
# {'thought': "The user is referring to a document on their screen, so we need to take a closer look at it to determine what's interesting. We don't have direct access to the user's screen, so we need to use a function that can capture the screen content.", 'search': '', 'function': 'take screenshot'}
# {'thought': "The user is asking about their desktop background, which is something that can be seen on their screen. To determine if it's appropriate, we need to visually inspect the background.", 'search': '', 'function': 'take screenshot'}
# {'thought': "The user is asking about the status of their laptop's power source. This information is not readily available online and requires real-time access to the user's laptop. It's not related to their physical appearance or environment, so webcam capture is not necessary. It's also not related to their clipboard content.", 'search': '', 'function': 'take screenshot'}
# {'thought': 'The user is asking for help with a math problem, which is a specific piece of information that can be found on the internet. The AI can search for the solution online.', 'search': 'math problem solution', 'function': 'search web'}
# {'thought': "The user is asking for help with a physical task, specifically changing a tire on their car. This task requires visual guidance and hands-on instruction. To provide the best assistance, it would be helpful to see the user's environment and the tire that needs to be changed.", 'search': 'car tire changing tutorial, tire changing instructions', 'function': 'capture webcam'}
# {'thought': "The user is asking for a joke, which is a form of entertainment that can be found online. I don't have a joke stored in my database, so I need to search the web for one.", 'search': 'funny jokes', 'function': 'search web'}

# %%
print(dut("How are you doing?"))
# Out:
# {'thought': "The user is asking about the AI's status, which is a general inquiry that doesn't require any specific information from the user's environment.", 'search': '', 'function': 'None'}
